# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cd
# Out:
# C:\Users\AE

# %%
data=pd.read_csv(r"Downloads/ML Project - Clustering Cancer Database U16955459050.csv")

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.shape
# Out:
# (569, 32)

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.isnull().any().sum()
# Out:
# 0

# %%
data.drop(columns=["id"],inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
data["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
data.drop(columns=["diagnosis"],inplace=True)

# %%
data
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
sns.pairplot(data[["radius_mean","texture_mean"]]);
# Out:
# C:\Users\AE\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\AE\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from sklearn.cluster import KMeans

# %%
km=KMeans(n_clusters=3)
data["cluster"]=km.fit_predict(data)
# Out:
# C:\Users\AE\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\AE\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
data["cluster"]
# Out:
# 0      2
# 1      2
# 2      2
# 3      0
# 4      2
#       ..
# 564    1
# 565    2
# 566    2
# 567    2
# 568    0
# Name: cluster, Length: 569, dtype: int32

# %%
df1=data[data["cluster"]==0]
df2=data[data["cluster"]==1]
df3=data[data["cluster"]==2]

# %%
plt.scatter(df1["radius_mean"],df1["texture_mean"],color="red")
plt.scatter(df2["radius_mean"],df2["texture_mean"],color="blue")
plt.scatter(df3["radius_mean"],df3["texture_mean"],color="green");

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
model=MinMaxScaler()

# %%
df=model.fit_transform(data[["radius_mean","texture_mean"]])

# %%
df
# Out:
# array([[0.52103744, 0.0226581 ],
#        [0.64314449, 0.27257355],
#        [0.60149557, 0.3902604 ],
#        ...,
#        [0.45525108, 0.62123774],
#        [0.64456434, 0.66351031],
#        [0.03686876, 0.50152181]])

# %%
df=pd.DataFrame(df,columns=[["radius_mean","texture_mean"]])

# %%
df
# Out:
#     radius_mean texture_mean
# 0      0.521037     0.022658
# 1      0.643144     0.272574
# 2      0.601496     0.390260
# 3      0.210090     0.360839
# 4      0.629893     0.156578
# ..          ...          ...
# 564    0.690000     0.428813
# 565    0.622320     0.626987
# 566    0.455251     0.621238
# 567    0.644564     0.663510
# 568    0.036869     0.501522
#
# [569 rows x 2 columns]

# %%
plt.scatter(df["radius_mean"],df["texture_mean"]);

# %%
from scipy.cluster.hierarchy import dendrogram,linkage

# %%
dendrogram(linkage(data,method="ward"),color_threshold=10000);

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
agg=AgglomerativeClustering(n_clusters=2,linkage="ward")

# %%
data["cluster"]=agg.fit_predict(data)

# %%
data
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(data,data["cluster"])
# Out:
# 0.6899797762083328

# %%
kmm=KMeans(n_clusters=2)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
wcss=[]
k_rng=range(1,10)
for i in k_rng:
    kmm=KMeans(n_clusters=i)
    kmm.fit(data[["radius_mean","texture_mean"]])
    wcss.append(kmm.inertia_)

# %%
plt.plot(k_rng,wcss);

# %%
kmm=KMeans(n_clusters=2)

# %%
data["cluster"]=kmm.fit_predict(data)

# %%
df1=data[data['cluster']==0]
df2=data[data['cluster']==1]

# %%
plt.scatter(df1["radius_mean"],df1["texture_mean"],color="orange")
plt.scatter(df2["radius_mean"],df2["texture_mean"],color="yellow")

# %%
silhouette_score(data,data["cluster"])
# Out:
# 0.6972647834018775

# %%
data
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...
